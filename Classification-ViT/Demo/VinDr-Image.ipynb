# %%
from Utils_VinDr import Utils
utils = Utils()

# %%
findings = utils.findings
findings.loc[findings['finding_birads'] == "BI-RADS 4"]
# Out:
# Empty DataFrame
# Columns: [study_id, series_id, image_id, laterality, view_position, height, width, breast_birads, breast_density, finding_categories, finding_birads, xmin, ymin, xmax, ymax, split]
# Index: []

# %%
utils.win_operation_save('43a9fff4ea9c4f7fa09d56c5583d2096') #0a6f0eac805822cd00f3c25ba99569e8
# Out:
# Imagen guardada exitosamente en /Users/julio/Library/Mobile Documents/com~apple~CloudDocs/Downloads.

# %%
utils.show_image('43a9fff4ea9c4f7fa09d56c5583d2096')
# Out:
# 1 - red - finding_categories: ['No Finding'],
# finding_birads: nan, breast_birads: BI-RADS 1, Photometric Interpretation: MONOCHROME2
# <Axes: >
