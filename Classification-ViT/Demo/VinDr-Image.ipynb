# %%
from Utils_VinDr import Utils
utils = Utils()

# %%
findings = utils.findings
findings.loc[findings['finding_birads'] == "BI-RADS 4"]
# Out:
#                               study_id                         series_id  \
# 0     48575a27b7c992427041a82fa750d3fa  26de4993fa6b8ae50a91c8baf49b92b0
# 1     48575a27b7c992427041a82fa750d3fa  26de4993fa6b8ae50a91c8baf49b92b0
# 4     c3487424fee1bdd4515b72dc3fd69813  77619c914263eae44e9099f1ce07192c
# 5     c3487424fee1bdd4515b72dc3fd69813  77619c914263eae44e9099f1ce07192c
# 8     7c51789da6c462e55bcb95c2a7d437ee  ac4d0771f6d7a7400ab463458f789dbe
# ...                                ...                               ...
# 2249  b8acac150be7f949f78dc631a3851f8b  f351166fe105bea6f090e38f41bc844c
# 2250  b8acac150be7f949f78dc631a3851f8b  f351166fe105bea6f090e38f41bc844c
# 2251  b8acac150be7f949f78dc631a3851f8b  f351166fe105bea6f090e38f41bc844c
# 2252  0bfd4fcebaba4e9c4086edd05044a75f  255af1dcf2e5342bcc6bae1fc1a918cd
# 2253  0bfd4fcebaba4e9c4086edd05044a75f  255af1dcf2e5342bcc6bae1fc1a918cd
#
#                               image_id laterality view_position  height  \
# ...

# %%
utils.win_operation_save('0a6f0eac805822cd00f3c25ba99569e8', name='masas') #0a6f0eac805822cd00f3c25ba99569e8
# Out:
# Imagen guardada exitosamente en /Users/julio/Library/Mobile Documents/com~apple~CloudDocs/Downloads.

# %%
utils.show_image('0a6f0eac805822cd00f3c25ba99569e8')
# Out:
# 1 - red - finding_categories: ['Mass'],
# finding_birads: BI-RADS 5, breast_birads: BI-RADS 5, Photometric Interpretation: MONOCHROME2
# <Axes: >
